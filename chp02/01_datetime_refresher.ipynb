# %%
import pandas as pd

df = pd.read_excel("https://archive.ics.uci.edu/ml/machine-learning-databases/00247/data_akbilgic.xlsx", skiprows=1)
# Out:
# /home/bilal326/Desktop/Time_Series/venv/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df.head()
# Out:
#         date       ISE     ISE.1        SP       DAX      FTSE    NIKKEI  \
# 0 2009-01-05  0.035754  0.038376 -0.004679  0.002193  0.003894  0.000000
# 1 2009-01-06  0.025426  0.031813  0.007787  0.008455  0.012866  0.004162
# 2 2009-01-07 -0.028862 -0.026353 -0.030469 -0.017833 -0.028735  0.017293
# 3 2009-01-08 -0.062208 -0.084716  0.003391 -0.011726 -0.000466 -0.040061
# 4 2009-01-09  0.009860  0.009658 -0.021533 -0.019873 -0.012710 -0.004474
#
#     BOVESPA        EU        EM
# 0  0.031190  0.012698  0.028524
# 1  0.018920  0.011341  0.008773
# 2 -0.035899 -0.017073 -0.020015
# 3  0.028283 -0.005561 -0.019424
# 4 -0.009764 -0.010989 -0.007802

# %%
df.dtypes
# Out:
# date       datetime64[ns]
# ISE               float64
# ISE.1             float64
# SP                float64
# DAX               float64
# FTSE              float64
# NIKKEI            float64
# BOVESPA           float64
# EU                float64
# EM                float64
# dtype: object

# %%
# Converting the date columns into pd.Timestamp/DatetimeIndex

df['date'] = pd.to_datetime(df['date'], yearfirst=True)

# %% [markdown]
# ### Using the .dt accessor and datetime properties

# %%
print(f"Min date: {df.date.min()}")
print(f"Max date: {df.date.max()}")
# Out:
# Min date: 2009-01-05 00:00:00
# Max date: 2011-02-22 00:00:00

# %%
# Indexing and slicing
df.set_index("date", inplace=True)

# %%
df.head()
# Out:
#                  ISE     ISE.1        SP       DAX      FTSE    NIKKEI  \
# date
# 2009-01-05  0.035754  0.038376 -0.004679  0.002193  0.003894  0.000000
# 2009-01-06  0.025426  0.031813  0.007787  0.008455  0.012866  0.004162
# 2009-01-07 -0.028862 -0.026353 -0.030469 -0.017833 -0.028735  0.017293
# 2009-01-08 -0.062208 -0.084716  0.003391 -0.011726 -0.000466 -0.040061
# 2009-01-09  0.009860  0.009658 -0.021533 -0.019873 -0.012710 -0.004474
#
#              BOVESPA        EU        EM
# date
# 2009-01-05  0.031190  0.012698  0.028524
# 2009-01-06  0.018920  0.011341  0.008773
# 2009-01-07 -0.035899 -0.017073 -0.020015
# 2009-01-08  0.028283 -0.005561 -0.019424
# 2009-01-09 -0.009764 -0.010989 -0.007802

# %% [markdown]
# ### Indexing and slicing

# %%
# Select all data after 2010-01-04(inclusive)
df['2010-01-04':]
# Out:
#                  ISE     ISE.1        SP       DAX      FTSE    NIKKEI  \
# date
# 2010-01-04  0.010229  0.014478  0.015916  0.000000  0.016018  0.000000
# 2010-01-05  0.013898  0.024019  0.003111 -0.002722  0.004028  0.002535
# 2010-01-06  0.007957  0.005706  0.000545  0.000409  0.001357  0.004635
# 2010-01-07  0.007772  0.007498  0.003993 -0.002484 -0.000597 -0.004650
# 2010-01-08 -0.003189  0.000835  0.002878  0.003027  0.001356  0.010862
# ...              ...       ...       ...       ...       ...       ...
# 2011-02-16  0.008599  0.013400  0.006238  0.001925  0.007952  0.005717
# 2011-02-17  0.009310  0.015977  0.003071 -0.001186  0.000345  0.002620
# 2011-02-18  0.000191 -0.001653  0.001923  0.002872 -0.000723  0.000568
# 2011-02-21 -0.013069 -0.013706 -0.020742 -0.014239 -0.011275  0.001358
# 2011-02-22 -0.007246 -0.019442  0.000000 -0.000473 -0.002997 -0.017920
#
#              BOVESPA        EU        EM
# date
# 2010-01-04  0.000000  0.016778  0.008399
# ...

# %%
# Select all data between 2010-01-04 and 2010-02-06(exclusive)
df.loc['2010-01-04':'2010-02-05']
# Out:
#                  ISE     ISE.1        SP       DAX      FTSE    NIKKEI  \
# date
# 2010-01-04  0.010229  0.014478  0.015916  0.000000  0.016018  0.000000
# 2010-01-05  0.013898  0.024019  0.003111 -0.002722  0.004028  0.002535
# 2010-01-06  0.007957  0.005706  0.000545  0.000409  0.001357  0.004635
# 2010-01-07  0.007772  0.007498  0.003993 -0.002484 -0.000597 -0.004650
# 2010-01-08 -0.003189  0.000835  0.002878  0.003027  0.001356  0.010862
# 2010-01-11 -0.016131 -0.006033  0.001745  0.000479  0.000704  0.007457
# 2010-01-12 -0.004549 -0.004339 -0.009425 -0.016273 -0.007140  0.000000
# 2010-01-13  0.017559  0.021362  0.008291  0.003383 -0.004593 -0.013335
# 2010-01-14  0.002074 -0.002076  0.002424  0.004307  0.004503  0.015955
# 2010-01-15 -0.013517 -0.015516 -0.010882 -0.019033 -0.007815  0.006800
# 2010-01-18  0.010044  0.013495  0.012422  0.007220  0.007123 -0.011634
# 2010-01-19  0.011098  0.007783  0.000000  0.009740  0.003398 -0.008342
# ...

# %%
# Select data between 2010-01 and 2010-06(both including)
df.loc['2010-01':'2010-06']
# Out:
#                  ISE     ISE.1        SP       DAX      FTSE    NIKKEI  \
# date
# 2010-01-04  0.010229  0.014478  0.015916  0.000000  0.016018  0.000000
# 2010-01-05  0.013898  0.024019  0.003111 -0.002722  0.004028  0.002535
# 2010-01-06  0.007957  0.005706  0.000545  0.000409  0.001357  0.004635
# 2010-01-07  0.007772  0.007498  0.003993 -0.002484 -0.000597 -0.004650
# 2010-01-08 -0.003189  0.000835  0.002878  0.003027  0.001356  0.010862
# ...              ...       ...       ...       ...       ...       ...
# 2010-06-24  0.000166 -0.008024 -0.016946 -0.014455 -0.015236  0.000467
# 2010-06-25 -0.000920 -0.003591  0.002855 -0.007366 -0.010585 -0.019411
# 2010-06-28  0.010132  0.016951 -0.002036  0.014168  0.004981 -0.004481
# 2010-06-29 -0.021816 -0.028443 -0.031508 -0.033893 -0.031547 -0.012798
# 2010-06-30 -0.006830 -0.006195 -0.010164  0.002264  0.000549 -0.019842
#
#              BOVESPA        EU        EM
# date
# 2010-01-04  0.000000  0.016778  0.008399
# ...

# %% [markdown]
# ### Creating date sequences and managing date offsets

# %%
pd.date_range(start="2018-01-20", end="2018-01-23", freq="D").astype(str).tolist()
# Out:
# ['2018-01-20', '2018-01-21', '2018-01-22', '2018-01-23']

# %%
pd.date_range(start="2018-01-20", periods=4, freq="M").astype(str).tolist()
# Out:
# /tmp/ipykernel_5062/2903091241.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.date_range(start="2018-01-20", periods=4, freq="M").astype(str).tolist()
# ['2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30']

# %% [markdown]
# ## Handling missing data

# %%
df2 = pd.read_csv("https://www.data.act.gov.au/resource/94a5-zqnn.csv")

# %%
df2.head()
# Out:
#      name                              gps                 datetime  no2  \
# 0  Florey  \n,  \n(-35.220606, 149.043539)  2025-06-24T03:00:00.000  0.0
# 1  Monash  \n,  \n(-35.418302, 149.094018)  2025-06-24T03:00:00.000  0.0
# 2   Civic  \n,  \n(-35.285307, 149.131579)  2025-06-24T03:00:00.000  NaN
# 3  Monash  \n,  \n(-35.418302, 149.094018)  2025-06-24T02:00:00.000  0.0
# 4  Florey  \n,  \n(-35.220606, 149.043539)  2025-06-24T02:00:00.000  0.0
#
#    o3_1hr  o3_4hr  o3_8hr    co  pm10_1_hr  pm2_5_1_hr  ...  aqi_co  aqi_no2  \
# 0   0.027   0.022   0.011  0.34       3.08        0.00  ...     3.0      0.0
# 1   0.026   0.021   0.012  1.05       0.00        4.97  ...    11.0      0.0
# 2   0.017   0.017   0.010  0.00       3.94        2.02  ...     0.0      0.0
# 3   0.025   0.015   0.009  1.11       0.00       12.42  ...    12.0      0.0
# 4   0.025   0.016   0.008  0.42       3.46        0.00  ...     4.0      0.0
#
# ...

# %%
df2[['date', 'pm2_5_1_hr']].isna().sum()
# Out:
# date          0
# pm2_5_1_hr    7
# dtype: int64

# %%
# df2['date'] = pd.to_datetime(df2['date'], yearfirst=True)
# df2.set_index("date", inplace=True)

df2a = df2[['datetime', 'pm2_5_1_hr']]
df2a['datetime'] = pd.to_datetime(df2a['datetime'], yearfirst=True)
df2a = df2a.set_index('datetime')
df2a.head()
# Out:
# /tmp/ipykernel_5062/3975363895.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2a['datetime'] = pd.to_datetime(df2a['datetime'], yearfirst=True)
#                      pm2_5_1_hr
# datetime
# 2025-06-24 03:00:00        0.00
# 2025-06-24 03:00:00        4.97
# 2025-06-24 03:00:00        2.02
# 2025-06-24 02:00:00       12.42
# 2025-06-24 02:00:00        0.00

# %%
print(df2a.index.min())
print(df2a.index.max())
# Out:
# 2025-06-10 01:00:00
# 2025-06-24 03:00:00

# %%
df2a[df2a['pm2_5_1_hr'].isna()]
# Out:
#                      pm2_5_1_hr
# datetime
# 2025-06-23 10:00:00         NaN
# 2025-06-23 09:00:00         NaN
# 2025-06-21 08:00:00         NaN
# 2025-06-21 07:00:00         NaN
# 2025-06-21 07:00:00         NaN
# 2025-06-21 06:00:00         NaN
# 2025-06-13 09:00:00         NaN

# %%
df2a.loc['2025-06-21'].isna().sum()
# Out:
# pm2_5_1_hr    4
# dtype: int64

# %%
import matplotlib.pyplot as plt
day_data = df2a.loc['2025-06-21']
plt.figure(figsize=(10, 5))
plt.plot(day_data.index, day_data['pm2_5_1_hr'], linestyle='-', color='blue', label='PM2.5 (1-hr)')
plt.xlabel('Time')
plt.ylabel('PM2.5 (1-hr)')
plt.title('PM2.5 on 2025-06-21 (Line breaks at NaNs)')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Methods to impute nulls:
# 1. ffill
# 2. bfill
# 3. fillna(df[].mean())
# 4. .interpolate(method="linear")
# 5. .interpolate(method="nearest")
# 6. .interpolate(method="spline", order=2)
# 7. .interpolate(method="polynomial", order=5)

# %% [markdown]
# Linear Interpolation
#
# $f(x) = f(x_0) + \frac{f(x_1) - f(x_0)}{x_1 - x_0}(x - x_0)$

# %% [markdown]
# Nearest Interpolation
#
# $f(x) = f(x_i) \quad \text{where} \quad x_i = \operatorname{argmin}_{x_k \in \text{known}} |x_k - x|$

# %% [markdown]
# Spline Interpolation
#
# $f_i(x) = a_i + b_i(x - x_i) + c_i(x - x_i)^2$

# %% [markdown]
# Polynomial Interpolation
#
# $f(x) = a_0 + a_1x + a_2x^2 + a_3x^3 + a_4x^4 + a_5x^5$

# %% [markdown]
# ## 📐 1. **Wide Format - Not recommended**
#
# ### 💡 Definition:
#
# * Each **row = one time point**
# * Each **column = one time series**
# * **Date** is in the index or a separate column
# * Most common in spreadsheets, classical time series tools (like Excel or statsmodels)
#
# ### 🧾 Example:
#
# | datetime   | sensor\_A | sensor\_B | sensor\_C |
# | ---------- | --------- | --------- | --------- |
# | 2025-06-21 | 3.1       | 5.2       | 8.3       |
# | 2025-06-22 | 3.3       | 5.1       | 8.5       |
# | 2025-06-23 | 3.2       | 5.3       | 8.4       |
#
#
#
# ## 🔁 2. **Expanded Format (aka Long Format)**
#
# ### 💡 Definition:
#
# * Each **row = one observation**
# * All time series go into **a single column**, with a separate identifier for which series it is
# * More aligned with **relational databases** and tidy data principles
#
# ### 🧾 Example:
#
# | datetime   | sensor\_id | value |
# | ---------- | ---------- | ----- |
# | 2025-06-21 | A          | 3.1   |
# | 2025-06-21 | B          | 5.2   |
# | 2025-06-21 | C          | 8.3   |
# | 2025-06-22 | A          | 3.3   |
# | 2025-06-22 | B          | 5.1   |
# | 2025-06-22 | C          | 8.5   |
#
#
# ## 🧳 3. **Compact Format**
#
# ### 💡 Definition:
#
# * Each **row = one full time series**
# * The **time dimension is stored in a list/array**
# * Needs two extra columns: `start_datetime` and `frequency`
#
# ### 🧾 Example:
#
# | sensor\_id | start\_datetime     | freq | values           |
# | ---------- | ------------------- | ---- | ---------------- |
# | A          | 2025-06-21 00:00:00 | 1D   | \[3.1, 3.3, 3.2] |
# | B          | 2025-06-21 00:00:00 | 1D   | \[5.2, 5.1, 5.3] |
# | C          | 2025-06-21 00:00:00 | 1D   | \[8.3, 8.5, 8.4] |
#
#
#
# ## 🧭 Summary Table
#
# | Feature        | Wide Format   | Expanded Format           | Compact Format                      |
# | -------------- | ------------- | ------------------------- | ----------------------------------- |
# | Rows           | = time points | = observations            | = time series                       |
# | Columns        | each series   | `id`, `datetime`, `value` | `id`, `values`, `start`, `freq`     |
# | Metadata       | Not supported | Easy to include           | Easy to include                     |
# | Time as        | Index/column  | Column                    | Implicit (via array + start + freq) |
# | Scaling        | Poor          | Excellent                 | Excellent                           |
# | Works with ML  | No            | Yes                       | Yes                                 |
# | Works with SQL | No            | Yes                       | Some effort needed                  |
#
#
#
# ### 🔮 Best Format for Time Series Forecasting
#
# The **best format** depends on your model and forecasting approach — but generally:
#
#
# ## ✅ **Best Overall: Expanded Format (a.k.a. Long Format)**
#
# ### Why?
#
# * **Most ML/DL libraries** (like Prophet, XGBoost, PyTorch Forecasting, GluonTS, etc.) expect or prefer this format.
# * **Scales easily** to many time series (multivariate or panel forecasting).
# * **Metadata-friendly**: allows adding features like region, category, etc.
# * **Compatible with time-varying features** (holidays, weather, lags, etc.).
# * **Easy to batch and feed into models.**
#
#
#
# ### 🔁 Example: Expanded Format
#
# | datetime   | series\_id | value | region | pricing\_type |
# | ---------- | ---------- | ----- | ------ | ------------- |
# | 2023-01-01 | A          | 123   | East   | Dynamic       |
# | 2023-01-01 | B          | 55    | West   | Standard      |
# | 2023-01-02 | A          | 140   | East   | Dynamic       |
#
# > This can be directly used in:
# >
# > * Facebook Prophet (with grouping logic)
# > * PyTorch Forecasting (`TimeSeriesDataSet`)
# > * XGBoost/LightGBM (after feature engineering)
#
#
# ## ✅ **Compact Format** — for deep learning models with regular time intervals
#
# ### Use if:
#
# * Your time series are **regularly sampled** (e.g., hourly/daily)
# * You're training **RNNs, Transformers, or Temporal CNNs**
# * You're using libraries like **tsai**, **Darts**, or **GluonTS**
#
# It is **memory-efficient** and well-suited for:
#
# * Storing long time series
# * Quick batch training
# * Reducing repeated timestamps
#
# But not ideal for:
#
# * Irregular sampling
# * Missing timestamps
# * External time-varying features
#
#
# ## ❌ **Wide Format** — not recommended
#
# * Hard to scale with many series
# * Not compatible with metadata or features
# * Difficult to use with most ML/DL tools
#
# Use it **only for EDA or classical univariate forecasting** (like ARIMA on one column).
#
#
# ## ✅ Conclusion
#
# | Goal                      | Best Format         |
# | ------------------------- | ------------------- |
# | ML / Deep Learning Models | **Expanded (long)** |
# | Memory-efficient storage  | **Compact**         |
# | Simple ARIMA on 1 series  | **Wide**            |
